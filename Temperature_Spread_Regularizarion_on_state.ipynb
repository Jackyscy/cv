# %% [markdown]
# <a href="https://colab.research.google.com/github/Jackyscy/cv/blob/main/Temperature_Spread_Regularizarion_on_state.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("2023_one hours__normal_on_state.csv", parse_dates=["Date_Time"],
        index_col=["Date_Time"],)

data.head()
# Out:
#                      Gt Exhaust Outlet Temp  Turbine Speed In RPM  \
# Date_Time
# 2023-01-20 17:00:00                 611.855              2999.121
# 2023-01-20 18:00:00                 604.004              3002.146
# 2023-01-20 19:00:00                 637.918              3001.744
# 2023-01-20 20:00:00                 636.447              3002.868
# 2023-01-20 21:00:00                 637.513              2998.669
#
#                      GT Fuel Gas Mass Flow  GT Gross MW  \
# Date_Time
# 2023-01-20 17:00:00                 13.760      231.782
# 2023-01-20 18:00:00                 13.175      226.570
# 2023-01-20 19:00:00                 11.979      207.629
# 2023-01-20 20:00:00                 12.306      212.659
# 2023-01-20 21:00:00                 11.290      193.451
#
#                      GT Compres Inlet Temp  GT IGV Position  \
# Date_Time
# 2023-01-20 17:00:00                 18.940           87.999
# 2023-01-20 18:00:00                 18.938           84.113
# 2023-01-20 19:00:00                 18.780           65.027
# 2023-01-20 20:00:00                 18.626           67.205
# 2023-01-20 21:00:00                 17.743           60.577
#
#                      GT Turbine Inlet Temperature  GT Swirl Angle  \
# Date_Time
# 2023-01-20 17:00:00                      1255.732          14.534
# 2023-01-20 18:00:00                      1244.014          19.430
# 2023-01-20 19:00:00                      1284.943          38.101
# 2023-01-20 20:00:00                      1283.541          33.234
# 2023-01-20 21:00:00                      1270.635          51.623
#
#                      GT Efficiency Actual (LHV)  GT (Expander) Efficiency  \
# Date_Time
# 2023-01-20 17:00:00                      34.919                    85.409
# 2023-01-20 18:00:00                      35.239                    85.504
# 2023-01-20 19:00:00                      35.913                    87.532
# 2023-01-20 20:00:00                      35.783                    87.373
# 2023-01-20 21:00:00                      35.513                    86.980
#
#                      ...  Turb Exhaust T/C 22  Turb Exhaust T/C 23  \
# Date_Time            ...
# 2023-01-20 17:00:00  ...              615.768              608.536
# 2023-01-20 18:00:00  ...              607.697              606.971
# 2023-01-20 19:00:00  ...              645.148              637.373
# 2023-01-20 20:00:00  ...              644.380              632.764
# 2023-01-20 21:00:00  ...              641.349              636.851
#
#                      Turb Exhaust T/C 24  Turb Exhaust T/C 25  \
# Date_Time
# 2023-01-20 17:00:00              605.209              601.492
# 2023-01-20 18:00:00              595.928              589.052
# 2023-01-20 19:00:00              643.240              637.800
# 2023-01-20 20:00:00              648.446              627.277
# 2023-01-20 21:00:00              641.639              638.126
#
#                      Turb Exhaust T/C 26  Turb Exhaust T/C 27  \
# Date_Time
# 2023-01-20 17:00:00              610.876              615.695
# 2023-01-20 18:00:00              595.202              609.593
# 2023-01-20 19:00:00              623.243              636.460
# 2023-01-20 20:00:00              618.795              641.789
# 2023-01-20 21:00:00              639.001              628.511
#
#                      Turb Exhaust T/C 28  Turb Exhaust T/C 29  \
# Date_Time
# 2023-01-20 17:00:00              628.713              611.376
# 2023-01-20 18:00:00              616.492              608.235
# 2023-01-20 19:00:00              648.020              645.099
# 2023-01-20 20:00:00              640.982              649.530
# 2023-01-20 21:00:00              633.543              643.794
#
#                      Turb Exhaust T/C 30  Turb Exhaust T/C 31
# Date_Time
# 2023-01-20 17:00:00              604.494              619.819
# 2023-01-20 18:00:00              600.413              600.202
# 2023-01-20 19:00:00              648.190              637.079
# 2023-01-20 20:00:00              641.044              630.275
# 2023-01-20 21:00:00              639.210              642.735
#
# [5 rows x 47 columns]

# %%
data.tail()
# Out:
#                      Gt Exhaust Outlet Temp  Turbine Speed In RPM  \
# Date_Time
# 2023-10-29 18:00:00                 631.871              2999.082
# 2023-10-29 19:00:00                 626.932              3002.417
# 2023-10-29 20:00:00                 627.254              2998.286
# 2023-10-29 21:00:00                 627.054              2997.869
# 2023-10-29 22:00:00                 623.723              3001.700
#
#                      GT Fuel Gas Mass Flow  GT Gross MW  \
# Date_Time
# 2023-10-29 18:00:00                 12.371      209.080
# 2023-10-29 19:00:00                 13.265      216.246
# 2023-10-29 20:00:00                 13.206      214.829
# 2023-10-29 21:00:00                 13.288      216.627
# 2023-10-29 22:00:00                 13.273      216.795
#
#                      GT Compres Inlet Temp  GT IGV Position  \
# Date_Time
# 2023-10-29 18:00:00                 26.803           76.402
# 2023-10-29 19:00:00                 26.510           87.982
# 2023-10-29 20:00:00                 26.462           87.990
# 2023-10-29 21:00:00                 26.232           87.984
# 2023-10-29 22:00:00                 25.943           88.004
#
#                      GT Turbine Inlet Temperature  GT Swirl Angle  \
# Date_Time
# 2023-10-29 18:00:00                      1270.740          36.868
# 2023-10-29 19:00:00                      1255.402          30.070
# 2023-10-29 20:00:00                      1253.733          31.251
# 2023-10-29 21:00:00                      1255.249          29.385
# 2023-10-29 22:00:00                      1252.697          28.859
#
#                      GT Efficiency Actual (LHV)  GT (Expander) Efficiency  \
# Date_Time
# 2023-10-29 18:00:00                      35.081                    85.716
# 2023-10-29 19:00:00                      33.778                    84.150
# 2023-10-29 20:00:00                      33.656                    83.951
# 2023-10-29 21:00:00                      33.780                    84.081
# 2023-10-29 22:00:00                      33.896                    84.335
#
#                      ...  Turb Exhaust T/C 22  Turb Exhaust T/C 23  \
# Date_Time            ...
# 2023-10-29 18:00:00  ...              632.941              635.023
# 2023-10-29 19:00:00  ...              628.389              626.967
# 2023-10-29 20:00:00  ...              630.019              627.262
# 2023-10-29 21:00:00  ...              628.844              626.230
# 2023-10-29 22:00:00  ...              625.089              624.296
#
#                      Turb Exhaust T/C 24  Turb Exhaust T/C 25  \
# Date_Time
# 2023-10-29 18:00:00              632.089              614.970
# 2023-10-29 19:00:00              614.922              612.110
# 2023-10-29 20:00:00              612.782              610.185
# 2023-10-29 21:00:00              613.153              609.790
# 2023-10-29 22:00:00              609.799              606.911
#
#                      Turb Exhaust T/C 26  Turb Exhaust T/C 27  \
# Date_Time
# 2023-10-29 18:00:00              619.824              645.096
# 2023-10-29 19:00:00              632.990              627.393
# 2023-10-29 20:00:00              632.697              628.726
# 2023-10-29 21:00:00              633.529              628.954
# 2023-10-29 22:00:00              631.486              626.173
#
#                      Turb Exhaust T/C 28  Turb Exhaust T/C 29  \
# Date_Time
# 2023-10-29 18:00:00              635.414              637.595
# 2023-10-29 19:00:00              636.445              629.851
# 2023-10-29 20:00:00              638.796              629.555
# 2023-10-29 21:00:00              640.118              630.300
# 2023-10-29 22:00:00              635.994              627.009
#
#                      Turb Exhaust T/C 30  Turb Exhaust T/C 31
# Date_Time
# 2023-10-29 18:00:00              632.764              625.949
# 2023-10-29 19:00:00              626.253              630.960
# 2023-10-29 20:00:00              622.468              630.057
# 2023-10-29 21:00:00              622.481              631.250
# 2023-10-29 22:00:00              619.739              626.640
#
# [5 rows x 47 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2743 entries, 2023-01-20 17:00:00 to 2023-10-29 22:00:00
# Data columns (total 47 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Gt Exhaust Outlet Temp           2743 non-null   float64
#  1   Turbine Speed In RPM             2743 non-null   float64
#  2   GT Fuel Gas Mass Flow            2743 non-null   float64
#  3   GT Gross MW                      2743 non-null   float64
#  4   GT Compres Inlet Temp            2743 non-null   float64
#  5   GT IGV Position                  2743 non-null   float64
#  6   GT Turbine Inlet Temperature     2743 non-null   float64
#  7   GT Swirl Angle                   2743 non-null   float64
#  8   GT Efficiency Actual (LHV)       2743 non-null   float64
#  9   GT (Expander) Efficiency         2743 non-null   float64
#  10  Combust Monitor Actual Spread 2  2743 non-null   float64
#  11  GT Compres Inlet Press           2743 non-null   float64
#  12  Combust Monitor Actual Spread 1  2743 non-null   float64
#  13  GT Exhaust Outlet Temp Exp       2743 non-null   float64
#  14  GT Exhaust Gas Flow - HB         2743 non-null   float64
#  15  Combust Monitor Actual Spread 3  2743 non-null   float64
#  16  Turb Exhaust T/C 1               2743 non-null   float64
#  17  Turb Exhaust T/C 2               2743 non-null   float64
#  18  Turb Exhaust T/C 3               2743 non-null   float64
#  19  Turb Exhaust T/C 4               2743 non-null   float64
#  20  Turb Exhaust T/C 5               2743 non-null   float64
#  21  Turb Exhaust T/C 6               2743 non-null   float64
#  22  Turb Exhaust T/C 7               2743 non-null   float64
#  23  Turb Exhaust T/C 8               2743 non-null   float64
#  24  Turb Exhaust T/C 9               2743 non-null   float64
#  25  Turb Exhaust T/C 10              2743 non-null   float64
#  26  Turb Exhaust T/C 11              2743 non-null   float64
#  27  Turb Exhaust T/C 12              2743 non-null   float64
#  28  Turb Exhaust T/C 13              2743 non-null   float64
#  29  Turb Exhaust T/C 14              2743 non-null   float64
#  30  Turb Exhaust T/C 15              2743 non-null   float64
#  31  Turb Exhaust T/C 16              2743 non-null   float64
#  32  Turb Exhaust T/C 17              2743 non-null   float64
#  33  Turb Exhaust T/C 18              2743 non-null   float64
#  34  Turb Exhaust T/C 19              2743 non-null   float64
#  35  Turb Exhaust T/C 20              2743 non-null   float64
#  36  Turb Exhaust T/C 21              2743 non-null   float64
#  37  Turb Exhaust T/C 22              2743 non-null   float64
#  38  Turb Exhaust T/C 23              2743 non-null   float64
#  39  Turb Exhaust T/C 24              2743 non-null   float64
#  40  Turb Exhaust T/C 25              2743 non-null   float64
#  41  Turb Exhaust T/C 26              2743 non-null   float64
#  42  Turb Exhaust T/C 27              2743 non-null   float64
#  43  Turb Exhaust T/C 28              2743 non-null   float64
#  44  Turb Exhaust T/C 29              2743 non-null   float64
#  45  Turb Exhaust T/C 30              2743 non-null   float64
#  46  Turb Exhaust T/C 31              2743 non-null   float64
# dtypes: float64(47)
# memory usage: 1.0 MB

# %%
fig, ax = plt.subplots(figsize=(25,25))

corr = data.corr()
sns.heatmap(corr , annot = True , ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Comment above: It is hard to see the number of correction for each features

# %%
#print("Slewness in Column: Combust Monitor Actual Spread 1", data["Combust Monitor Actual Spread 1"].skew)

#plt.hist(data["Combust Monitor Actual Spread 1"])
#plt.show()

# %% [markdown]
# Normal disctribustion can be used for the

# %%
#from scipy import stats

#col_cox , lam = stats.boxcox(data["Combust Monitor Actual Spread 1"])[0:2]
#print("Skewness in Column : Sqrt Combust Monitor Actual Spread 1s " ,pd.Series(col_cox).skew())

#plt.hist(col_cox)
#plt.show()

# %%
#data["Combust Monitor Actual Spread 1"] = col_cox

# %%
remaining_columns = list(data.columns)
remaining_columns.remove("Combust Monitor Actual Spread 1")

# %%
X = data[remaining_columns].values
Y = data['Combust Monitor Actual Spread 1'].values

# %%
from sklearn.model_selection import train_test_split

Xtrain , Xtest , Ytrain , Ytest = train_test_split(X , Y , test_size = 0.2 , random_state = 4)

# %%
from sklearn.preprocessing import StandardScaler

Scaler = StandardScaler()
Xtrain = Scaler.fit_transform(Xtrain)
Xtest = Scaler.transform(Xtest)

# %%
Xtrain.shape , Xtest.shape
# Out:
# ((2194, 46), (549, 46))

# %%
# check whether data is standardized or not
# mean should be 1

plt.ylim(-1,1)

means = []
for i in range(X.shape[1]):
    means.append(np.mean(Xtest[:,i]))
plt.plot(means , scaley=False)

# %%
# Check variances

plt.ylim(0,2)

vars = []
for i in range(X.shape[1]):
    vars.append(np.var(Xtest[:,i]))
plt.plot(vars)

# %%
from sklearn.linear_model import Ridge , Lasso , ElasticNet , LinearRegression

# %%
model_linear = LinearRegression()
model_linear.fit(Xtrain , Ytrain)
print(" Training Accuracy : " , model_linear.score(Xtrain , Ytrain))
print(" Testing Accuracy : " , model_linear.score(Xtest , Ytest))
# Out:
#  Training Accuracy :  0.878378556657698
#  Testing Accuracy :  0.8899098324462105

# %%
# Let's now plot the feature's importance
# according to the linear model.

# Create series with feature importance.
tmp = pd.Series(np.abs(model_linear.coef_))

# Let's add the variable names.
Xtrain = pd.DataFrame(Xtrain)
tmp.index = Xtrain.columns

# Let's make a bar plot.
tmp.plot.bar(figsize=(15, 6))
plt.title("Feature importance")
plt.ylabel("Importance")
# Out:
# Text(0, 0.5, 'Importance')

# %%
# if the data set has less number of features and the features have less correlations among themselves
model_ridge = Ridge()
model_ridge.fit(Xtrain , Ytrain)
print(" Training Accuracy : " , model_ridge.score(Xtrain , Ytrain))
print(" Testing Accuracy : " , model_ridge.score(Xtest , Ytest))
# Out:
#  Training Accuracy :  0.8782295477309067
#  Testing Accuracy :  0.889763615452662

# %%
# Let's now plot the feature's importance
# according to the Ridge model.

# Create series with feature importance.
tmp = pd.Series(np.abs(model_ridge.coef_))

# Let's add the variable names.
Xtrain = pd.DataFrame(Xtrain)
tmp.index = Xtrain.columns

# Let's make a bar plot.
tmp.plot.bar(figsize=(15, 6))
plt.title("Feature importance")
plt.ylabel("Importance")
# Out:
# Text(0, 0.5, 'Importance')

# %%
# Using Lasso the weight of few features will become zero. this will lead data loss
model_lasso = Lasso()
model_lasso.fit(Xtrain , Ytrain)
print(" Training Accuracy : " , model_lasso.score(Xtrain , Ytrain))
print(" Testing Accuracy : " , model_lasso.score(Xtest , Ytest))
# Out:
#  Training Accuracy :  0.5988833765836379
#  Testing Accuracy :  0.5905767945188434

# %%
# Let's now plot the feature's importance
# according to the Lasso model.

# Create series with feature importance.
tmp = pd.Series(np.abs(model_lasso.coef_))

# Let's add the variable names.
Xtrain = pd.DataFrame(Xtrain)
tmp.index = Xtrain.columns

# Let's make a bar plot.
tmp.plot.bar(figsize=(15, 6))
plt.title("Feature importance")
plt.ylabel("Importance")
# Out:
# Text(0, 0.5, 'Importance')

# %%
# Elastic

# lambda_1*L1 + lambda_2*L2
# alpha = lambda_1 + lambda_2 , l1_ratio = lambda_1/(lambda_1 + lambda_2)

model_elasticnet = ElasticNet()
model_elasticnet.fit(Xtrain , Ytrain)
print(" Training Accuracy : " , model_elasticnet.score(Xtrain , Ytrain))
print(" Testing Accuracy : " , model_elasticnet.score(Xtest , Ytest))
# Out:
#  Training Accuracy :  0.6400604099312781
#  Testing Accuracy :  0.6377169646752099

# %%
# Let's now plot the feature's importance
# according to the Elastic model.

# Create series with feature importance.
tmp = pd.Series(np.abs(model_elasticnet.coef_))

# Let's add the variable names.
Xtrain = pd.DataFrame(Xtrain)
tmp.index = Xtrain.columns

# Let's make a bar plot.
tmp.plot.bar(figsize=(15, 6))
plt.title("Feature importance")
plt.ylabel("Importance")
# Out:
# Text(0, 0.5, 'Importance')

# %% [markdown]
# Changing Parameter for Lasso and ElasticNet

# %%
model_Lasso_alpha = Lasso(alpha = 0.01)
model_Lasso_alpha.fit(Xtrain , Ytrain)
print(" Training Accuracy : " , model_Lasso_alpha.score(Xtrain , Ytrain))
print(" Testing Accuracy : " , model_Lasso_alpha.score(Xtest , Ytest))
# Out:
#  Training Accuracy :  0.8690252811331932
#  Testing Accuracy :  0.8819060155285013
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.323e+01, tolerance: 3.034e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Let's now plot the feature's importance
# according to the Lasso model.

# Create series with feature importance.
tmp = pd.Series(np.abs(model_Lasso_alpha.coef_))

# Let's add the variable names.
Xtrain = pd.DataFrame(Xtrain)
tmp.index = Xtrain.columns

# Let's make a bar plot.
tmp.plot.bar(figsize=(15, 6))
plt.title("Feature importance")
plt.ylabel("Importance")
# Out:
# Text(0, 0.5, 'Importance')

# %%
# Elastic

# lambda_1*L1 + lambda_2*L2
# alpha = lambda_1 + lambda_2 , l1_ratio = lambda_1/(lambda_1 + lambda_2)

model_elasticnet_alpha = ElasticNet(alpha = 0.01 + 0.01 , l1_ratio = 0.01/(0.01 + 0.01))
model_elasticnet_alpha.fit(Xtrain , Ytrain)
print(" Training Accuracy : " , model_elasticnet_alpha.score(Xtrain , Ytrain))
print(" Testing Accuracy : " , model_elasticnet_alpha.score(Xtest , Ytest))
# Out:
#  Training Accuracy :  0.8624393807041705
#  Testing Accuracy :  0.8760011575596411
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.112e+01, tolerance: 3.034e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Let's now plot the feature's importance
# according to the Elastic model.

# Create series with feature importance.
tmp = pd.Series(np.abs(model_elasticnet_alpha.coef_))

# Let's add the variable names.
Xtrain = pd.DataFrame(Xtrain)
tmp.index = Xtrain.columns

# Let's make a bar plot.
tmp.plot.bar(figsize=(15, 6))
plt.title("Feature importance")
plt.ylabel("Importance")
# Out:
# Text(0, 0.5, 'Importance')

# %%
model_Lasso_large_alpha = Lasso(alpha=0.06, random_state=0)

model_Lasso_large_alpha.fit(Xtrain, Ytrain)
print(" Training Accuracy : " , model_Lasso_large_alpha.score(Xtrain , Ytrain))
print(" Testing Accuracy : " , model_Lasso_large_alpha.score(Xtest , Ytest))
# Out:
#  Training Accuracy :  0.8331693084973933
#  Testing Accuracy :  0.8455275007407123

# %%
# Let's now plot the feature's importance
# according to the Lasso model.

# Create series with feature importance.
tmp = pd.Series(np.abs(model_Lasso_large_alpha.coef_))

# Let's add the variable names.
Xtrain = pd.DataFrame(Xtrain)
tmp.index = Xtrain.columns

# Let's make a bar plot.
tmp.plot.bar(figsize=(15, 6))
plt.title("Feature importance")
plt.ylabel("Importance")
# Out:
# Text(0, 0.5, 'Importance')
