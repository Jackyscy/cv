# %% [markdown]
# <a href="https://colab.research.google.com/github/Jackyscy/cv/blob/main/Temperature_Spread_RFECV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("GT data for 3-hour intervel learning1.csv", parse_dates=["Date_Time"],
        index_col=["Date_Time"],)

data.head()
# Out:
#                      Combust Monitor Actual Spread 1  Turb Exhaust T1  \
# Date_Time
# 2021-09-05 13:50:00                        31.056818       617.558472
# 2021-09-05 16:50:00                        29.123943       617.433899
# 2021-09-05 19:50:00                        29.981073       617.737305
# 2021-09-06 10:50:00                        29.942198       616.953918
# 2021-09-06 13:50:00                        27.763840       616.664490
#
#                      Turb Exhaust T2  Turb Exhaust T3  Turb Exhaust T4  \
# Date_Time
# 2021-09-05 13:50:00       630.641113       623.100586       624.433838
# 2021-09-05 16:50:00       627.732971       620.316772       625.417481
# 2021-09-05 19:50:00       626.815002       620.644348       626.150207
# 2021-09-06 10:50:00       624.698975       621.066834       625.358582
# 2021-09-06 13:50:00       623.856750       619.643860       624.923584
#
#                      Turb Exhaust T5  Turb Exhaust T6  Turb Exhaust T7  \
# Date_Time
# 2021-09-05 13:50:00       622.997681       629.324280       624.259338
# 2021-09-05 16:50:00       625.806457       631.588562       623.166626
# 2021-09-05 19:50:00       626.840393       632.476074       623.707764
# 2021-09-06 10:50:00       623.719666       631.418030       620.302856
# 2021-09-06 13:50:00       625.768555       631.285461       621.734375
#
#                      Turb Exhaust T8  Turb Exhaust T9  ...  Combust Ref Temp  \
# Date_Time                                              ...
# 2021-09-05 13:50:00       613.819336       614.424744  ...       1323.189209
# 2021-09-05 16:50:00       613.281372       616.283813  ...       1323.006714
# 2021-09-05 19:50:00       613.928162       616.272095  ...       1324.548096
# 2021-09-06 10:50:00       611.742188       617.621704  ...       1324.031982
# 2021-09-06 13:50:00       612.153931       616.143250  ...       1322.438599
#
#                      GT Compres Disch Press  GT Compres Discharge Temp  \
# Date_Time
# 2021-09-05 13:50:00             1506.065918                 409.284668
# 2021-09-05 16:50:00             1495.955322                 410.848724
# 2021-09-05 19:50:00             1503.727417                 410.733215
# 2021-09-06 10:50:00             1492.666870                 412.803863
# 2021-09-06 13:50:00             1484.694092                 412.501587
#
#                      GT Compres Inlet Temp  GT Exhaust Gas Flow  \
# Date_Time
# 2021-09-05 13:50:00              29.372759           617.549011
# 2021-09-05 16:50:00              30.342381           616.006531
# 2021-09-05 19:50:00              30.131554           619.785584
# 2021-09-06 10:50:00              30.939713           611.674560
# 2021-09-06 13:50:00              30.283035           618.603455
#
#                      GT Fuel Gas Mass Flow  GT IGV Position  \
# Date_Time
# 2021-09-05 13:50:00              12.966751        87.996284
# 2021-09-05 16:50:00              12.882809        87.994431
# 2021-09-05 19:50:00              12.721853        87.991333
# 2021-09-06 10:50:00              12.585037        88.001442
# 2021-09-06 13:50:00              12.714616        88.000969
#
#                      GT Turbine Inlet Temp  GT Gross MW  \
# Date_Time
# 2021-09-05 13:50:00            1246.550537   211.845764
# 2021-09-05 16:50:00            1247.431152   211.376907
# 2021-09-05 19:50:00            1247.777954   212.360016
# 2021-09-06 10:50:00            1248.785034   209.649109
# 2021-09-06 13:50:00            1246.161621   210.130875
#
#                      GT Baseload Power Output Expected
# Date_Time
# 2021-09-05 13:50:00                         229.368973
columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3239 entries, 2021-09-05 13:50:00 to 2023-09-05 13:50:00
# Data columns (total 51 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Combust Monitor Actual Spread 1    3239 non-null   float64
#  1   Turb Exhaust T1                    3239 non-null   float64
#  2   Turb Exhaust T2                    3239 non-null   float64
#  3   Turb Exhaust T3                    3239 non-null   float64
#  4   Turb Exhaust T4                    3239 non-null   float64
#  5   Turb Exhaust T5                    3239 non-null   float64
#  6   Turb Exhaust T6                    3239 non-null   float64
#  7   Turb Exhaust T7                    3239 non-null   float64
#  8   Turb Exhaust T8                    3239 non-null   float64
#  9   Turb Exhaust T9                    3239 non-null   float64
#  10  Turb Exhaust T10                   3239 non-null   float64
#  11  Turb Exhaust T11                   3239 non-null   float64
#  12  Turb Exhaust T12                   3239 non-null   float64
#  13  Turb Exhaust T13                   3239 non-null   float64
#  14  Turb Exhaust T14                   3239 non-null   float64
#  15  Turb Exhaust T15                   3239 non-null   float64
#  16  Turb Exhaust T16                   3239 non-null   float64
#  17  Turb Exhaust T17                   3239 non-null   float64
#  18  Turb Exhaust T18                   3239 non-null   float64
#  19  Turb Exhaust T19                   3239 non-null   float64
#  20  Turb Exhaust T20                   3239 non-null   float64
#  21  Turb Exhaust T21                   3239 non-null   float64
#  22  Turb Exhaust T22                   3239 non-null   float64
#  23  Turb Exhaust T23                   3239 non-null   float64
#  24  Turb Exhaust T24                   3239 non-null   float64
#  25  Turb Exhaust T25                   3239 non-null   float64
#  26  Turb Exhaust T26                   3239 non-null   float64
#  27  Turb Exhaust T27                   3239 non-null   float64
#  28  Turb Exhaust T28                   3239 non-null   float64
#  29  Turb Exhaust T29                   3239 non-null   float64
#  30  Turb Exhaust T30                   3239 non-null   float64
#  31  Turb Exhaust T31                   3239 non-null   float64
#  32  GT Exhaust Outlet Temp             3239 non-null   float64
#  33  GT Exhaust Outlet temp Expected    3239 non-null   float64
#  34  Combust Monitor Actual Spread 2    3239 non-null   float64
#  35  Combust Monitor Actual Spread 3    3239 non-null   float64
#  36  GT Exhaust Outlet temp Average     3239 non-null   float64
#  37  GT Swirl Angle                     3239 non-null   float64
#  38  GT Efficiency Actual (LHV)         3239 non-null   float64
#  39  GT Efficiency Expected (LHV)       3239 non-null   float64
#  40  Turbine Speed in RPM               3239 non-null   float64
#  41  Combust Ref Temp                   3239 non-null   float64
#  42  GT Compres Disch Press             3239 non-null   float64
#  43  GT Compres Discharge Temp          3239 non-null   float64
#  44  GT Compres Inlet Temp              3239 non-null   float64
#  45  GT Exhaust Gas Flow                3239 non-null   float64
#  46  GT Fuel Gas Mass Flow              3239 non-null   float64
#  47  GT IGV Position                    3239 non-null   float64
#  48  GT Turbine Inlet Temp              3239 non-null   float64
#  49  GT Gross MW                        3239 non-null   float64
#  50  GT Baseload Power Output Expected  3239 non-null   float64
# dtypes: float64(51)
# memory usage: 1.3 MB

# %%
fig, ax = plt.subplots(figsize=(50,50))

corr = data.corr()
sns.heatmap(corr , annot = True , ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Comment above: It is hard to see the number of correction for each features

# %%
#print("Slewness in Column: Combust Monitor Actual Spread 1", data["Combust Monitor Actual Spread 1"].skew)

#plt.hist(data["Combust Monitor Actual Spread 1"])
#plt.show()

# %% [markdown]
# Normal disctribustion can be used for the

# %%
#from scipy import stats

#col_cox , lam = stats.boxcox(data["Combust Monitor Actual Spread 1"])[0:2]
#print("Skewness in Column : Sqrt Combust Monitor Actual Spread 1s " ,pd.Series(col_cox).skew())

#plt.hist(col_cox)
#plt.show()

# %%
#data["Combust Monitor Actual Spread 1"] = col_cox

# %%
remaining_columns = list(data.columns)
remaining_columns.remove("Combust Monitor Actual Spread 1")

# %%
X = data[remaining_columns].values
Y = data['Combust Monitor Actual Spread 1'].values

# %%
from sklearn.model_selection import train_test_split

Xtrain , Xtest , Ytrain , Ytest = train_test_split(X , Y , test_size = 0.2 , random_state = 4)

# %%
from sklearn.preprocessing import StandardScaler

Scaler = StandardScaler()
Xtrain = Scaler.fit_transform(Xtrain)
Xtest = Scaler.transform(Xtest)

# %%
Xtrain.shape , Xtest.shape
# Out:
# ((2591, 50), (648, 50))

# %%
# check whether data is standardized or not
# mean should be 1

plt.ylim(-1,1)

means = []
for i in range(X.shape[1]):
    means.append(np.mean(Xtest[:,i]))
plt.plot(means , scaley=False)

# %%
# Check variances

plt.ylim(0,2)

vars = []
for i in range(X.shape[1]):
    vars.append(np.var(Xtest[:,i]))
plt.plot(vars)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFECV

model = LinearRegression()
rfecv = RFECV(model , step = 1, min_features_to_select = 13 , n_jobs = -1)
rfecv.fit(Xtrain , Ytrain)
# Out:
# RFECV(estimator=LinearRegression(), min_features_to_select=13, n_jobs=-1)

# %%
rfecv.support_
# Out:
# array([False,  True, False,  True, False, False,  True,  True, False,
#        False,  True, False,  True,  True, False, False,  True,  True,
#         True, False,  True,  True, False,  True,  True,  True,  True,
#        False,  True, False,  True, False, False,  True, False, False,
#        False,  True, False, False,  True, False, False, False, False,
#        False, False,  True, False, False])

# %%
rfecv.ranking_
# Out:
# array([17,  1, 21,  1,  5, 13,  1,  1, 12,  6,  1, 11,  1,  1, 22,  9,  1,
#         1,  1, 10,  1,  1, 16,  1,  1,  1,  1, 15,  1, 23,  1, 19,  4,  1,
#        14, 25,  2,  1, 28, 29,  1,  7, 24, 20, 27, 26,  8,  1,  3, 18])

# %%
selected_features = np.where(rfecv.support_)[0]
Xtrain = Xtrain[:,selected_features]
Xtest = Xtest[:,selected_features]

# %%
selected_features
# Out:
# array([ 1,  3,  6,  7, 10, 12, 13, 16, 17, 18, 20, 21, 23, 24, 25, 26, 28,
#        30, 33, 37, 40, 47])

# %%
model.fit(Xtrain , Ytrain)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ -6.81625725,   6.0416055 ,   3.89229447,  -9.00729461,
#         -2.74463396,   5.1606233 , -13.31543146, -11.23873893,
#         -2.1216514 ,  16.60604669,   9.25125703,   7.45722649,
#          3.25663285,  -4.52854563,   2.2175337 ,   3.40398571,
#         -3.05898141,  -6.99014509,   5.03308536,  -3.31777129,
#          1.98124182,   2.96509233])

# %%
model.intercept_
# Out:
# 29.16222911644306

# %%
model.coef_.dot(Xtest[10,:]) + model.intercept_
# Out:
# 28.636551472167383

# %%
model.score(Xtest , Ytest)
# Out:
# 0.9055932468692457
